# %%
import pandas as pd
import matplotlib.pyplot as plt
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
ts=ts.cumsum()
ts.plot()

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=['a','b','c','d'])
df=df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best')

# %%
from pandas import Series
s=Series([1,4,'ww','tt'])
s
# Out:
# 0     1
# 1     4
# 2    ww
# 3    tt
# dtype: object

# %%
df.to_csv('foo.csv')
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          a          b          c         d
# 0    2000-01-01  -0.795994  -0.303637   0.962839 -1.009166
# 1    2000-01-02  -0.456586  -0.597088   1.659052 -2.273481
# 2    2000-01-03  -0.562294  -1.099149   1.119344 -2.651615
# 3    2000-01-04   0.755602  -1.695041   1.549495 -3.076662
# 4    2000-01-05   0.582756  -3.151261   2.522363 -2.016886
# ..          ...        ...        ...        ...       ...
# 995  2002-09-22  -9.698928 -25.384734 -39.184879  1.762175
# 996  2002-09-23 -10.655394 -24.104124 -40.425668  1.695600
# 997  2002-09-24 -10.607450 -22.586371 -39.827606  2.064752
# 998  2002-09-25 -12.113393 -24.511927 -39.812994  1.655494
# 999  2002-09-26 -13.037808 -23.869312 -39.263082  1.990725
#
# [1000 rows x 5 columns]

# %%
df.to_excel('foo.xlsx',sheet_name='sheet1')
pd.read_excel('foo.xlsx','sheet1',index_col=None,na_values=['NA'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-090b23a55b87> in <module>
# ----> 1 df.to_excel('foo.xlsx',sheet_name='sheet1')
#       2 pd.read_excel('foo.xlsx','sheet1',index_col=None,na_values=['NA'])
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2254             startcol=startcol,
#    2255             freeze_panes=freeze_panes,
# -> 2256             engine=engine,
#    2257         )
#    2258
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# ...

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111)
ax.set(xlim=[0.5,4.5],ylim=[-2,8],title='An Example Axes',ylabel='Y-Axis',xlabel='X-Axis')
plt.show()

# %%
fig=plt.figure()
ax1=fig.add_subplot(231)
ax2=fig.add_subplot(224)
ax3=fig.add_subplot(333)

# %%
x=np.linspace(0,np.pi)
y_sin=np.sin(x)
y_cos=np.cos(x)
ax1.plot(x,y_sin)

# %%
x=np.arange(10)
y=np.random.randn(10)
plt.scatter(x,y,color='red',marker='+')
plt.show()

# %%
labels='Frogs','Hogs','Dogs','Logs'
sizes=[15,30,45,10]
explode=(0,0.2,0,0.3)
fig1,(ax1,ax2)=plt.subplots(2)
ax1.pie(sizes,labels=labels,autopct='%1.0f%%',shadow=True)
ax1.axis('equal')
ax2.pie(sizes,autopct='%1.1f%%',shadow=True,startangle=100,explode=explode,pctdistance=1.2)
ax2.axis('equal')
ax2.legend(labels=labels,loc='upper right')

# %%
from matplotlib import pyplot as plt

# %%
fig,(ax1,ax2)=plt.subplots(2)
ax1.boxplot(3)#data(3)
ax2.boxplot(3,vert=False) #控制方向
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fea39e0f28>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fea39ed630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fea39d4518>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fea39edcc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fea39f6048>],
#  'means': []}

# %%
N=50
x=np.random.randn(N)
y=np.random.randn(N)
color=np.random.randn(N)
area=(30*np.random.randn(N))**2 #0 to 15 point radii
plt.scatter(x,y,s=area,c=color,alpha=0.5)
plt.show()
